# %%
import gzip
import json

with gzip.open("../data/raw/2020-09-28-04-45_965.json.gz", "rt", encoding="utf-8") as f:
    run = json.load(f)

print(type(run))
# Out:
# <class 'list'>

# %%
print(type(run))
print(len(run))
# Out:
# <class 'list'>
# 965

# %%
print(type(run[0]))
# Out:
# <class 'dict'>

# %%
print(run[0].keys())
# Out:
# dict_keys(['event'])

# %%
event = run[0]['event']
print(type(event))
# Out:
# <class 'dict'>

# %%
print(event.keys())
# Out:
# dict_keys(['gold_per_floor', 'floor_reached', 'playtime', 'items_purged', 'score', 'play_id', 'local_time', 'is_ascension_mode', 'campfire_choices', 'neow_cost', 'seed_source_timestamp', 'circlet_count', 'master_deck', 'special_seed', 'relics', 'potions_floor_usage', 'damage_taken', 'seed_played', 'potions_obtained', 'is_trial', 'path_per_floor', 'character_chosen', 'items_purchased', 'campfire_rested', 'item_purchase_floors', 'current_hp_per_floor', 'gold', 'neow_bonus', 'is_prod', 'is_daily', 'chose_seed', 'campfire_upgraded', 'win_rate', 'timestamp', 'path_taken', 'build_version', 'purchased_purges', 'victory', 'max_hp_per_floor', 'card_choices', 'player_experience', 'relics_obtained', 'event_choices', 'is_beta', 'boss_relics', 'items_purged_floors', 'is_endless', 'potions_floor_spawned', 'killed_by', 'ascension_level'])

# %%
card_choices = event['card_choices']
print(type(card_choices))
print(len(card_choices))
print(card_choices[0])
# Out:
# <class 'list'>
# 12
# {'not_picked': ['Sunder', 'Stack'], 'picked': 'Hologram', 'floor': 1.0}

# %%
picks = [c['picked'] for c in card_choices]
print(set(picks))
# Out:
# {'Melter', 'SKIP', 'Ball Lightning', 'Redo', 'Sunder', 'Static Discharge', 'Hologram', 'Electrodynamics', 'Consume+1', 'Streamline'}

# %%
lengths = [len(c['not_picked']) for c in card_choices]
print(set(lengths))
# Out:
# {2, 3}

# %%
lengths = [len(c['not_picked']) for c in card_choices]
print(set(lengths))
# Out:
# {2, 3}

# %%
print(event['floor_reached'])
print(len(event['path_per_floor']), event['path_per_floor'][:5])
print(len(event['current_hp_per_floor']), event['current_hp_per_floor'][:5])
print(event['relics'][:5])
print(event['master_deck'][:5])
print(event['character_chosen'])
print(event['victory'])
# Out:
# 24
# 24 ['M', 'M', '?', '?', 'M']
# 25 [68, 68, 68, 68, 68]
# ['Cracked Core', 'NeowsBlessing', 'Ice Cream', 'Bottled Flame', 'Lantern']
# ['Strike_B', 'Strike_B', 'Strike_B', 'Defend_B', 'Defend_B']
# DEFECT
# False

# %%
print(len(run))
# Out:
# 965

# %%
run[:20]
# Out:
# [{'event': {'gold_per_floor': [109,
#     125,
#     125,
#     125,
#     145,
#     145,
#     180,
#     199,
#     275,
#     275,
#     80,
#     99,
#     99,
#     114,
#     114,
#     219,
#     219,
#     230,
#     242,
#     22,
#     40,
#     52,
#     52,
#     52,
#     52],
#    'floor_reached': 24,
#    'playtime': 1078,
#    'items_purged': ['Strike_B'],
#    'score': 260,
#    'play_id': '115c855c-c8a8-434f-b83d-2fd0a9b217ca',
#    'local_time': '20200928143538',
#    'is_ascension_mode': True,
#    'campfire_choices': [{'data': 'Redo', 'floor': 6.0, 'key': 'SMITH'},
#     {'floor': 10.0, 'key': 'REST'},
#     {'floor': 15.0, 'key': 'REST'},
#     {'floor': 23, 'key': 'REST'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 341443592492300,
#    'circlet_count': 0,
#    'master_deck': ['Strike_B',
#     'Strike_B',
#     'Strike_B',
#     'Defend_B',
#     'Defend_B',
#     'Defend_B+1',
#     'Defend_B',
#     'Zap+1',
#     'Dualcast+1',
#     'Hologram+1',
#     'Streamline',
#     'Redo+1',
#     'Ball Lightning',
#     'Sunder',
#     'Conserve Battery',
#     'Static Discharge',
#     'Zap',
#     'Static Discharge',
#     'Biased Cognition',
#     'Redo',
#     'Electrodynamics',
#     'Ball Lightning',
#     'Melter',
#     'Consume+1'],
#    'special_seed': 0,
#    'relics': ['Cracked Core',
#     'NeowsBlessing',
#     'Ice Cream',
#     'Bottled Flame',
#     'Lantern',
#     'Inserter',
#     'War Paint'],
#    'potions_floor_usage': [24],
#    'damage_taken': [{'damage': 0.0,
#      'enemies': '2 Louse',
#      'floor': 1.0,
#      'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Small Slimes', 'floor': 2.0, 'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Cultist', 'floor': 5.0, 'turns': 1.0},
#     {'damage': 20.0, 'enemies': '3 Sentries', 'floor': 7.0, 'turns': 8.0},
#     {'damage': 26.0, 'enemies': 'Gremlin Gang', 'floor': 8.0, 'turns': 3.0},
#     {'damage': 8.0, 'enemies': 'Blue Slaver', 'floor': 12.0, 'turns': 2.0},
#     {'damage': 11.0, 'enemies': 'Lots of Slimes', 'floor': 14.0, 'turns': 2.0},
#     {'damage': 25.0, 'enemies': 'Hexaghost', 'floor': 16.0, 'turns': 6.0},
#     {'damage': 6.0,
#      'enemies': 'Spheric Guardian',
#      'floor': 18.0,
#      'turns': 3.0},
#     {'damage': 1.0, 'enemies': '3 Byrds', 'floor': 19.0, 'turns': 2.0},
#     {'damage': 7, 'enemies': 'Cultist and Chosen', 'floor': 21, 'turns': 4},
#     {'damage': 25, 'enemies': 'Snake Plant', 'floor': 22, 'turns': 3},
#     {'damage': 46, 'enemies': 'Book of Stabbing', 'floor': 24, 'turns': 3}],
#    'seed_played': '-8180205324450871629',
#    'potions_obtained': [{'floor': 2.0, 'key': 'Weak Potion'},
#     {'floor': 8.0, 'key': 'EssenceOfSteel'},
#     {'floor': 14.0, 'key': 'SkillPotion'},
#     {'floor': 16.0, 'key': 'Energy Potion'},
#     {'floor': 22, 'key': 'Ancient Potion'}],
#    'is_trial': False,
#    'path_per_floor': ['M',
#     'M',
#     '?',
#     '?',
#     'M',
#     'R',
#     'E',
#     'M',
#     'T',
#     'R',
#     '$',
#     'M',
#     '?',
#     'M',
#     'R',
#     'B',
#     None,
#     'M',
#     'M',
#     '$',
#     'M',
#     'M',
#     'R',
#     'E'],
#    'character_chosen': 'DEFECT',
#    'items_purchased': ['Lantern', 'Conserve Battery', 'War Paint'],
#    'campfire_rested': 3,
#    'item_purchase_floors': [11, 11, 20],
#    'current_hp_per_floor': [68,
#     68,
#     68,
#     68,
#     68,
#     68,
#     48,
#     22,
#     22,
#     44,
#     44,
#     36,
#     36,
#     25,
#     47,
#     22,
#     62,
#     56,
#     55,
#     55,
#     48,
#     23,
#     45,
#     0,
#     0],
#    'gold': 52,
#    'neow_bonus': 'THREE_ENEMY_KILL',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 1,
#    'win_rate': 0,
#    'timestamp': 1601267738,
#    'path_taken': ['M',
#     'M',
#     '?',
#     '?',
#     '?',
#     'R',
#     'E',
#     'M',
#     'T',
#     'R',
#     '$',
#     '?',
#     '?',
#     '?',
#     'R',
#     'BOSS',
#     'M',
#     'M',
#     '$',
#     'M',
#     'M',
#     'R',
#     'E'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 1,
#    'victory': False,
#    'max_hp_per_floor': [75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75],
#    'card_choices': [{'not_picked': ['Sunder', 'Stack'],
#      'picked': 'Hologram',
#      'floor': 1.0},
#     {'not_picked': ['Go for the Eyes', 'Leap'],
#      'picked': 'Streamline',
#      'floor': 2.0},
#     {'not_picked': ['Turbo', 'Machine Learning'],
#      'picked': 'Redo',
#      'floor': 5.0},
#     {'not_picked': ['Reinforced Body', 'Compile Driver'],
#      'picked': 'Ball Lightning',
#      'floor': 7.0},
#     {'not_picked': ['Streamline', 'Double Energy'],
#      'picked': 'Sunder',
#      'floor': 8.0},
#     {'not_picked': ['Gash', 'FTL'],
#      'picked': 'Static Discharge',
#      'floor': 12.0},
#     {'not_picked': ['Undo', 'Streamline'], 'picked': 'Redo', 'floor': 14.0},
#     {'not_picked': ['Core Surge', 'Buffer'],
#      'picked': 'Electrodynamics',
#      'floor': 16.0},
#     {'not_picked': ['Heatsinks', 'White Noise'],
#      'picked': 'Ball Lightning',
#      'floor': 18.0},
#     {'not_picked': ['White Noise', 'Gash'], 'picked': 'Melter', 'floor': 19.0},
#     {'not_picked': ['Beam Cell', 'Stack', 'Streamline'],
#      'picked': 'SKIP',
#      'floor': 21},
#     {'not_picked': ['Rebound+1', 'Machine Learning'],
#      'picked': 'Consume+1',
#      'floor': 22}],
#    'player_experience': 979320,
#    'relics_obtained': [{'floor': 7.0, 'key': 'Ice Cream'},
#     {'floor': 9.0, 'key': 'Bottled Flame'}],
#    'event_choices': [{'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Living Wall',
#      'player_choice': 'Grow',
#      'floor': 3.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'cards_upgraded': ['Zap']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Upgrade Shrine',
#      'player_choice': 'Upgraded',
#      'floor': 4.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'cards_upgraded': ['Hologram']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Match and Keep!',
#      'player_choice': '3 cards matched',
#      'floor': 13.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'cards_obtained': ['Zap', 'Static Discharge', 'Biased Cognition']}],
#    'is_beta': False,
#    'boss_relics': [{'not_picked': ['Black Star', 'Astrolabe'],
#      'picked': 'Inserter'}],
#    'items_purged_floors': [20],
#    'is_endless': False,
#    'potions_floor_spawned': [2, 8, 14, 16, 22],
#    'killed_by': 'Book of Stabbing',
#    'ascension_level': 6}},
#  {'event': {'gold_per_floor': [110,
#     60,
#     74,
#     92,
#     62,
#     62,
#     97,
#     107,
#     107,
#     139,
#     139,
#     149,
#     167,
#     19,
#     19,
#     123,
#     123,
#     140,
#     140,
#     65,
#     77,
#     6,
#     6,
#     39,
#     39,
#     62,
#     62,
#     62,
#     72,
#     91,
#     91,
#     91,
#     189,
#     239,
#     256,
#     256,
#     17,
#     67,
#     67,
#     101,
#     117,
#     134,
#     210,
#     242,
#     242,
#     242,
#     253,
#     279,
#     279,
#     279,
#     279,
#     279,
#     0,
#     0,
#     0],
#    'floor_reached': 54,
#    'playtime': 2562,
#    'items_purged': ['Strike_B'],
#    'score': 862,
#    'play_id': '161fa9d8-97aa-4109-8c58-27061dce8eb6',
#    'local_time': '20200928123537',
#    'is_ascension_mode': True,
#    'campfire_choices': [{'data': 'Dualcast', 'floor': 6.0, 'key': 'SMITH'},
#     {'data': 'Zap', 'floor': 11.0, 'key': 'SMITH'},
#     {'floor': 15.0, 'key': 'REST'},
#     {'data': 'Storm', 'floor': 23.0, 'key': 'SMITH'},
#     {'data': 'Heatsinks', 'floor': 25.0, 'key': 'SMITH'},
#     {'data': 'Self Repair', 'floor': 28.0, 'key': 'SMITH'},
#     {'floor': 32.0, 'key': 'REST'},
#     {'data': 'Madness', 'floor': 45, 'key': 'SMITH'},
#     {'floor': 49, 'key': 'RECALL'},
#     {'data': 'Madness', 'floor': 52, 'key': 'SMITH'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 88623420838000,
#    'circlet_count': 0,
#    'master_deck': ['Strike_B',
#     'Defend_B+1',
#     'Defend_B',
#     'Defend_B',
#     'Defend_B',
#     'Zap+1',
#     'Dualcast+1',
#     'Conserve Battery',
#     'Self Repair+1',
#     'Static Discharge+1',
#     'Sunder',
#     'Self Repair',
#     'Ball Lightning',
#     'Cold Snap',
#     'Heatsinks+1',
#     'Capacitor',
#     'Melter',
#     'Meteor Strike',
#     'Self Repair',
#     'Capacitor',
#     'Storm+1',
#     'Glacier',
#     'Seek',
#     'Madness+1',
#     'Madness+1',
#     'Self Repair+1',
#     'Coolheaded+1',
#     'Storm'],
#    'special_seed': 0,
#    'relics': ['Cracked Core',
#     'NeowsBlessing',
#     'Toy Ornithopter',
#     'Happy Flower',
#     'Sundial',
#     'Orrery',
#     'Busted Crown',
#     'Pantograph',
#     'Bottled Lightning',
#     'Strawberry',
#     'Tiny House',
#     'Mummified Hand',
#     'Bird Faced Urn',
#     'Dream Catcher',
#     'Eternal Feather',
#     'Toxic Egg 2',
#     'Medical Kit'],
#    'potions_floor_usage': [44, 44, 48, 50, 54, 54],
#    'damage_taken': [{'damage': 0.0,
#      'enemies': '2 Louse',
#      'floor': 1.0,
#      'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Cultist', 'floor': 3.0, 'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Small Slimes', 'floor': 4.0, 'turns': 2.0},
#     {'damage': 48.0, 'enemies': 'Gremlin Nob', 'floor': 7.0, 'turns': 5.0},
#     {'damage': 4.0, 'enemies': 'Blue Slaver', 'floor': 8.0, 'turns': 4.0},
#     {'damage': 23.0, 'enemies': '3 Sentries', 'floor': 10.0, 'turns': 5.0},
#     {'damage': 15.0, 'enemies': '2 Fungi Beasts', 'floor': 12.0, 'turns': 4.0},
#     {'damage': 11.0, 'enemies': 'Looter', 'floor': 13.0, 'turns': 2.0},
#     {'damage': 34.0, 'enemies': 'Hexaghost', 'floor': 16.0, 'turns': 9.0},
#     {'damage': 6.0, 'enemies': '3 Byrds', 'floor': 18.0, 'turns': 3.0},
#     {'damage': 12.0, 'enemies': 'Chosen', 'floor': 21.0, 'turns': 4.0},
#     {'damage': 37.0, 'enemies': 'Slavers', 'floor': 24.0, 'turns': 3.0},
#     {'damage': 31.0, 'enemies': '3 Cultists', 'floor': 29.0, 'turns': 5.0},
#     {'damage': 30.0,
#      'enemies': 'Centurion and Healer',
#      'floor': 30.0,
#      'turns': 4.0},
#     {'damage': 51.0, 'enemies': 'Champ', 'floor': 33.0, 'turns': 11.0},
#     {'damage': 32.0, 'enemies': '3 Darklings', 'floor': 35.0, 'turns': 4.0},
#     {'damage': 0.0,
#      'enemies': 'Mind Bloom Boss Battle',
#      'floor': 38.0,
#      'turns': 4.0},
#     {'damage': 55.0, 'enemies': 'Nemesis', 'floor': 40.0, 'turns': 8.0},
#     {'damage': 0.0, 'enemies': '3 Shapes', 'floor': 41.0, 'turns': 3.0},
#     {'damage': 23.0, 'enemies': '3 Darklings', 'floor': 42.0, 'turns': 6.0},
#     {'damage': 75, 'enemies': 'Giant Head', 'floor': 44, 'turns': 8},
#     {'damage': 36, 'enemies': 'Maw', 'floor': 47, 'turns': 7},
#     {'damage': 87, 'enemies': 'Reptomancer', 'floor': 48, 'turns': 5},
#     {'damage': 93, 'enemies': 'Time Eater', 'floor': 50, 'turns': 8},
#     {'damage': 109, 'enemies': 'Shield and Spear', 'floor': 54, 'turns': 3}],
#    'seed_played': '3758658912346938927',
#    'potions_obtained': [{'floor': 4.0, 'key': 'FearPotion'},
#     {'floor': 5.0, 'key': 'FairyPotion'},
#     {'floor': 5.0, 'key': 'EssenceOfDarkness'},
#     {'floor': 8.0, 'key': 'BlessingOfTheForge'},
#     {'floor': 16.0, 'key': 'Fire Potion'},
#     {'floor': 18.0, 'key': 'GamblersBrew'},
#     {'floor': 24.0, 'key': 'ColorlessPotion'},
#     {'floor': 29.0, 'key': 'Fire Potion'},
#     {'floor': 34.0, 'key': 'DistilledChaos'},
#     {'floor': 44, 'key': 'PowerPotion'},
#     {'floor': 47, 'key': 'BlessingOfTheForge'},
#     {'floor': 48, 'key': 'SteroidPotion'}],
#    'is_trial': False,
#    'path_per_floor': ['M',
#     '?',
#     'M',
#     'M',
#     '?',
#     'R',
#     'E',
#     'M',
#     'T',
#     'E',
#     'R',
#     'M',
#     'M',
#     '$',
#     'R',
#     'B',
#     None,
#     'M',
#     'T',
#     '?',
#     'M',
#     '$',
#     'R',
#     'E',
#     'R',
#     'T',
#     '?',
#     'R',
#     'M',
#     'M',
#     '?',
#     'R',
#     'B',
#     None,
#     'M',
#     '?',
#     '$',
#     '?',
#     '?',
#     'E',
#     'M',
#     'M',
#     'T',
#     'E',
#     'R',
#     '?',
#     'M',
#     'E',
#     'R',
#     'B',
#     None,
#     'R',
#     '$',
#     'E'],
#    'character_chosen': 'DEFECT',
#    'items_purchased': ['Orrery',
#     'Storm',
#     'Mummified Hand',
#     'Medical Kit',
#     'PowerPotion'],
#    'campfire_rested': 2,
#    'item_purchase_floors': [14, 22, 37, 53, 53],
#    'current_hp_per_floor': [75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     34,
#     37,
#     37,
#     26,
#     26,
#     18,
#     7,
#     7,
#     29,
#     32,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     52,
#     52,
#     59,
#     59,
#     59,
#     52,
#     46,
#     46,
#     70,
#     55,
#     87,
#     79,
#     68,
#     68,
#     87,
#     87,
#     68,
#     87,
#     87,
#     87,
#     60,
#     75,
#     75,
#     87,
#     50,
#     65,
#     37,
#     87,
#     87,
#     87,
#     0,
#     0],
#    'gold': 0,
#    'neow_bonus': 'THREE_ENEMY_KILL',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 7,
#    'win_rate': 0,
#    'timestamp': 1601267737,
#    'path_taken': ['M',
#     '?',
#     'M',
#     'M',
#     '?',
#     'R',
#     'E',
#     '?',
#     'T',
#     'E',
#     'R',
#     '?',
#     'M',
#     '$',
#     'R',
#     'BOSS',
#     'M',
#     '?',
#     '?',
#     'M',
#     '$',
#     'R',
#     'E',
#     'R',
#     'T',
#     '?',
#     'R',
#     'M',
#     '?',
#     '?',
#     'R',
#     'BOSS',
#     'M',
#     '?',
#     '$',
#     '?',
#     '?',
#     'E',
#     'M',
#     '?',
#     'T',
#     'E',
#     'R',
#     '?',
#     'M',
#     'E',
#     'R',
#     'BOSS',
#     'R',
#     '$',
#     'E'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 1,
#    'victory': False,
#    'max_hp_per_floor': [75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     75,
#     82,
#     82,
#     82,
#     82,
#     82,
#     82,
#     82,
#     82,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87,
#     87],
#    'card_choices': [{'not_picked': ['Stack', 'Steam'],
#      'picked': 'Conserve Battery',
#      'floor': 1.0},
#     {'not_picked': ['Redo', 'Steam', 'Hologram'],
#      'picked': 'SKIP',
#      'floor': 3.0},
#     {'not_picked': ['Cold Snap', 'Rebound'],
#      'picked': 'Self Repair',
#      'floor': 4.0},
#     {'not_picked': ['Rip and Tear', 'Melter'],
#      'picked': 'Static Discharge',
#      'floor': 7.0},
#     {'not_picked': ['Aggregate', 'Sweeping Beam', 'Steam'],
#      'picked': 'SKIP',
#      'floor': 8.0},
#     {'not_picked': ['BootSequence', 'Auto Shields', 'Multi-Cast'],
#      'picked': 'SKIP',
#      'floor': 10.0},
#     {'not_picked': ['Leap', 'Redo'], 'picked': 'Sunder', 'floor': 12.0},
#     {'not_picked': ['Gash', 'Redo'], 'picked': 'Self Repair', 'floor': 13.0},
#     {'not_picked': ['Hologram', 'Chaos'],
#      'picked': 'Ball Lightning',
#      'floor': 14.0},
#     {'not_picked': ['Tempest', 'Stack'], 'picked': 'Cold Snap', 'floor': 14.0},
#     {'not_picked': ['Hologram', 'Skim'], 'picked': 'Heatsinks', 'floor': 14.0},
#     {'not_picked': ['Compile Driver', 'Stack'],
#      'picked': 'Capacitor',
#      'floor': 14.0},
#     {'not_picked': ['Sweeping Beam', 'Hologram'],
#      'picked': 'Melter',
#      'floor': 14.0},
#     {'not_picked': ['Hyperbeam', 'Machine Learning'],
#      'picked': 'Meteor Strike',
#      'floor': 16.0},
#     {'not_picked': [], 'picked': 'Self Repair', 'floor': 18.0},
#     {'not_picked': [], 'picked': 'Capacitor', 'floor': 21.0},
#     {'not_picked': ['Go for the Eyes'], 'picked': 'SKIP', 'floor': 24.0},
#     {'not_picked': ['Go for the Eyes'], 'picked': 'SKIP', 'floor': 24.0},
#     {'not_picked': ['Beam Cell'], 'picked': 'SKIP', 'floor': 29.0},
#     {'not_picked': ['Conserve Battery+1'], 'picked': 'SKIP', 'floor': 30.0},
#     {'not_picked': [], 'picked': 'Seek', 'floor': 33.0},
#     {'not_picked': ['Hologram'], 'picked': 'SKIP', 'floor': 35.0},
#     {'not_picked': [], 'picked': 'Self Repair+1', 'floor': 40.0},
#     {'not_picked': ['Steam'], 'picked': 'SKIP', 'floor': 41.0},
#     {'not_picked': [], 'picked': 'Coolheaded+1', 'floor': 42.0},
#     {'not_picked': [], 'picked': 'Barrage+1', 'floor': 44},
#     {'not_picked': ['Cold Snap'], 'picked': 'SKIP', 'floor': 47},
#     {'not_picked': [], 'picked': 'Storm', 'floor': 48}],
#    'player_experience': 389500,
#    'relics_obtained': [{'floor': 7.0, 'key': 'Toy Ornithopter'},
#     {'floor': 9.0, 'key': 'Happy Flower'},
#     {'floor': 10.0, 'key': 'Sundial'},
#     {'floor': 19.0, 'key': 'Pantograph'},
#     {'floor': 24.0, 'key': 'Bottled Lightning'},
#     {'floor': 26.0, 'key': 'Strawberry'},
#     {'floor': 38.0, 'key': 'Bird Faced Urn'},
#     {'floor': 40.0, 'key': 'Dream Catcher'},
#     {'floor': 44, 'key': 'Eternal Feather'},
#     {'floor': 48, 'key': 'Toxic Egg 2'}],
#    'event_choices': [{'cards_removed': ['Strike_B'],
#      'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'The Cleric',
#      'player_choice': 'Card Removal',
#      'floor': 2.0,
#      'gold_loss': 50.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'The Woman in Blue',
#      'player_choice': 'Bought 2 Potions',
#      'floor': 5.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'cards_removed': ['Strike_B'],
#      'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Beggar',
#      'player_choice': 'Gave Gold',
#      'floor': 20.0,
#      'gold_loss': 75.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Accursed Blacksmith',
#      'player_choice': 'Forge',
#      'floor': 27.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'cards_upgraded': ['Static Discharge']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'The Library',
#      'player_choice': 'Read',
#      'floor': 31.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'cards_obtained': ['Glacier']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Winding Halls',
#      'player_choice': 'Embrace Madness',
#      'floor': 36.0,
#      'gold_loss': 0.0,
#      'damage_taken': 11.0,
#      'cards_obtained': ['Madness', 'Madness']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'MindBloom',
#      'player_choice': 'Fight',
#      'floor': 38.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'SensoryStone',
#      'player_choice': 'Memory 1',
#      'floor': 39.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'cards_removed': ['Barrage'],
#      'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Removed Attack',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Falling',
#      'floor': 46,
#      'gold_loss': 0}],
#    'is_beta': False,
#    'boss_relics': [{'not_picked': ['Inserter', 'Snecko Eye'],
#      'picked': 'Busted Crown'},
#     {'not_picked': ['SacredBark', 'FrozenCore'], 'picked': 'Tiny House'}],
#    'items_purged_floors': [53],
#    'is_endless': False,
#    'potions_floor_spawned': [4, 8, 16, 18, 24, 29, 33, 38, 42, 44, 47, 48],
#    'killed_by': 'Shield and Spear',
#    'ascension_level': 3}},
#  {'event': {'gold_per_floor': [117, 137, 137, 62, 82, 82],
#    'floor_reached': 5,
#    'playtime': 124,
#    'items_purged': ['Strike_R'],
#    'score': 62,
#    'play_id': '70063305-4267-4074-b26e-fca92daf5d10',
#    'local_time': '20200928123536',
#    'is_ascension_mode': True,
#    'campfire_choices': [],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 1925431984000,
#    'circlet_count': 0,
#    'master_deck': ['AscendersBane',
#     'Strike_R',
#     'Strike_R',
#     'Strike_R',
#     'Strike_R',
#     'Defend_R',
#     'Defend_R',
#     'Defend_R',
#     'Defend_R',
#     'Bash'],
#    'relics': ['Burning Blood', 'NeowsBlessing'],
#    'potions_floor_usage': [],
#    'damage_taken': [{'damage': 0,
#      'enemies': 'Small Slimes',
#      'floor': 1,
#      'turns': 1},
#     {'damage': 0, 'enemies': 'Cultist', 'floor': 2, 'turns': 1},
#     {'damage': 0, 'enemies': '2 Louse', 'floor': 5, 'turns': 1}],
#    'seed_played': '-1263913920904990750',
#    'potions_obtained': [{'floor': 3, 'key': 'LiquidBronze'},
#     {'floor': 3, 'key': 'DistilledChaos'}],
#    'is_trial': False,
#    'path_per_floor': ['M', 'M', '?', '$', 'M'],
#    'character_chosen': 'IRONCLAD',
#    'items_purchased': [],
#    'campfire_rested': 0,
#    'item_purchase_floors': [],
#    'current_hp_per_floor': [74, 75, 75, 75, 75, 75],
#    'gold': 82,
#    'neow_bonus': 'THREE_ENEMY_KILL',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 0,
#    'win_rate': 0,
#    'timestamp': 1601267736,
#    'path_taken': ['M', 'M', '?', '$', '?'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 1,
#    'victory': False,
#    'max_hp_per_floor': [75, 75, 75, 75, 75, 75],
#    'card_choices': [{'not_picked': ['Clothesline', 'Rage', 'Infernal Blade'],
#      'picked': 'SKIP',
#      'floor': 1},
#     {'not_picked': ['Thunderclap', 'Pummel', 'Searing Blow'],
#      'picked': 'SKIP',
#      'floor': 2}],
#    'player_experience': 987359,
#    'relics_obtained': [],
#    'event_choices': [{'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Got Potions',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Lab',
#      'floor': 3,
#      'gold_loss': 0}],
#    'is_beta': False,
#    'boss_relics': [],
#    'items_purged_floors': [4],
#    'is_endless': False,
#    'potions_floor_spawned': [5],
#    'killed_by': '2 Louse',
#    'ascension_level': 20}},
#  {'event': {'gold_per_floor': [116,
#     116,
#     116,
#     132,
#     57,
#     57,
#     88,
#     107,
#     107,
#     107,
#     107],
#    'floor_reached': 10,
#    'playtime': 271,
#    'items_purged': ['Strike_R'],
#    'score': 122,
#    'play_id': '7df2cbf8-7b42-4fd7-b549-1d2e1aca25a7',
#    'local_time': '20200928123537',
#    'is_ascension_mode': True,
#    'campfire_choices': [{'data': 'Bash', 'floor': 6, 'key': 'SMITH'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 349133536519600,
#    'circlet_count': 0,
#    'master_deck': ['AscendersBane',
#     'Strike_R',
#     'Strike_R',
#     'Defend_R',
#     'Defend_R',
#     'Defend_R',
#     'Defend_R',
#     'Bash+1',
#     'Body Slam',
#     'Armaments',
#     'Entrench',
#     'Sword Boomerang'],
#    'special_seed': 0,
#    'relics': ['Burning Blood', 'Vajra', 'Self Forming Clay'],
#    'potions_floor_usage': [7],
#    'damage_taken': [{'damage': 8.0,
#      'enemies': 'Small Slimes',
#      'floor': 1.0,
#      'turns': 5.0},
#     {'damage': 9, 'enemies': 'Jaw Worm', 'floor': 4, 'turns': 4},
#     {'damage': 53, 'enemies': 'Lagavulin', 'floor': 7, 'turns': 10},
#     {'damage': 0, 'enemies': 'Cultist', 'floor': 8, 'turns': 3},
#     {'damage': 13, 'enemies': 'Large Slime', 'floor': 10, 'turns': 5}],
#    'seed_played': '8398157327044926603',
#    'potions_obtained': [{'floor': 4, 'key': 'SkillPotion'}],
#    'is_trial': False,
#    'path_per_floor': ['M', '?', '?', 'M', '$', 'R', 'E', 'M', 'T', 'M'],
#    'character_chosen': 'IRONCLAD',
#    'items_purchased': [],
#    'campfire_rested': 0,
#    'item_purchase_floors': [],
#    'current_hp_per_floor': [66, 66, 59, 56, 56, 56, 9, 15, 15, 2, 2],
#    'gold': 107,
#    'neow_bonus': 'REMOVE_CARD',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 1,
#    'win_rate': 0,
#    'timestamp': 1601267737,
#    'path_taken': ['M', '?', '?', 'M', '$', 'R', 'E', 'M', 'T', 'M'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 1,
#    'victory': False,
#    'max_hp_per_floor': [75, 75, 75, 75, 75, 75, 75, 75, 75, 75, 75],
#    'card_choices': [{'not_picked': ['Shrug It Off', 'Warcry'],
#      'picked': 'Body Slam',
#      'floor': 1.0},
#     {'not_picked': ['Rage', 'Heavy Blade'], 'picked': 'Armaments', 'floor': 4},
#     {'not_picked': ['Fiend Fire', 'Dual Wield'],
#      'picked': 'Entrench',
#      'floor': 7},
#     {'not_picked': ['Heavy Blade', 'Flex'],
#      'picked': 'Sword Boomerang',
#      'floor': 8}],
#    'player_experience': 340199,
#    'relics_obtained': [{'floor': 7, 'key': 'Vajra'},
#     {'floor': 9, 'key': 'Self Forming Clay'}],
#    'event_choices': [{'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Ignored',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Shining Light',
#      'floor': 2,
#      'gold_loss': 0},
#     {'cards_removed': ['Strike_R'],
#      'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Card Removal',
#      'damage_taken': 7,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Golden Wing',
#      'floor': 3,
#      'gold_loss': 0}],
#    'is_beta': False,
#    'boss_relics': [],
#    'items_purged_floors': [5],
#    'is_endless': False,
#    'potions_floor_spawned': [4],
#    'killed_by': 'Large Slime',
#    'ascension_level': 17}},
#  {'event': {'gold_per_floor': [118, 136, 136, 101, 101, 101, 101, 101],
#    'floor_reached': 7,
#    'playtime': 375,
#    'items_purged': [],
#    'score': 39,
#    'play_id': '6c1dba8f-e441-4964-b2b7-a5fb9f71d139',
#    'local_time': '20200928003536',
#    'is_ascension_mode': False,
#    'campfire_choices': [{'data': 'Quick Slash', 'floor': 6, 'key': 'SMITH'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 47628361321100,
#    'circlet_count': 0,
#    'master_deck': ['Strike_G',
#     'Strike_G',
#     'Strike_G',
#     'Strike_G+1',
#     'Strike_G',
#     'Defend_G',
#     'Defend_G',
#     'Defend_G',
#     'Defend_G',
#     'Defend_G',
#     'Survivor',
#     'Neutralize',
#     'Quick Slash+1',
#     'Poisoned Stab+1'],
#    'relics': ['Runic Pyramid', 'Golden Idol'],
#    'potions_floor_usage': [],
#    'damage_taken': [{'damage': 0,
#      'enemies': 'Cultist',
#      'floor': 1,
#      'turns': 4},
#     {'damage': 1, 'enemies': 'Jaw Worm', 'floor': 2, 'turns': 4},
#     {'damage': 21, 'enemies': 'Gremlin Nob', 'floor': 7, 'turns': 5}],
#    'seed_played': '5570025215475185706',
#    'potions_obtained': [{'floor': 2, 'key': 'Explosive Potion'}],
#    'is_trial': False,
#    'path_per_floor': ['M', 'M', '?', '?', '?', 'R', 'E'],
#    'character_chosen': 'THE_SILENT',
#    'items_purchased': [],
#    'campfire_rested': 0,
#    'item_purchase_floors': [],
#    'current_hp_per_floor': [70, 69, 55, 70, 53, 53, 32, 32],
#    'gold': 101,
#    'neow_bonus': 'BOSS_RELIC',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 1,
#    'win_rate': 0.0,
#    'timestamp': 1601267736,
#    'path_taken': ['M', 'M', '?', '?', '?', 'R', 'E'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 0,
#    'victory': False,
#    'max_hp_per_floor': [70, 70, 70, 70, 70, 70, 70, 70],
#    'card_choices': [{'not_picked': ['Dagger Spray', 'Prepared'],
#      'picked': 'Quick Slash',
#      'floor': 1},
#     {'not_picked': ['Dash', 'Choke'], 'picked': 'Poisoned Stab', 'floor': 2}],
#    'player_experience': 17523,
#    'relics_obtained': [],
#    'event_choices': [{'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Entered Light',
#      'damage_taken': 14,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Shining Light',
#      'floor': 3,
#      'gold_loss': 0,
#      'cards_upgraded': ['Strike_G', 'Poisoned Stab']},
#     {'damage_healed': 17,
#      'gold_gain': 0,
#      'player_choice': 'Healed',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'The Cleric',
#      'floor': 4,
#      'gold_loss': 35},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Take Damage',
#      'damage_taken': 17,
#      'relics_obtained': ['Golden Idol'],
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Golden Idol',
#      'floor': 5,
#      'gold_loss': 0}],
#    'is_beta': False,
#    'boss_relics': [],
#    'items_purged_floors': [],
#    'is_endless': False,
#    'potions_floor_spawned': [2],
#    'killed_by': 'Gremlin Nob',
#    'ascension_level': 0}},
#  {'event': {'gold_per_floor': [118,
#     4,
#     79,
#     79,
#     103,
#     139,
#     163,
#     163,
#     163,
#     198,
#     148,
#     161,
#     179,
#     58,
#     58,
#     182,
#     182,
#     200,
#     221,
#     33,
#     56,
#     72,
#     72,
#     72,
#     91,
#     137,
#     137,
#     137,
#     152,
#     152,
#     152,
#     152],
#    'floor_reached': 31,
#    'playtime': 2548,
#    'items_purged': ['Strike_B', 'Glacier+1'],
#    'score': 367,
#    'play_id': '48aa93e5-c51a-4369-9f9f-5629cd876edb',
#    'local_time': '20200928003538',
#    'is_ascension_mode': False,
#    'campfire_choices': [{'data': 'Zap', 'floor': 8, 'key': 'SMITH'},
#     {'data': 'Scrape', 'floor': 15, 'key': 'SMITH'},
#     {'floor': 24, 'key': 'REST'},
#     {'data': 'Beam Cell', 'floor': 27, 'key': 'SMITH'},
#     {'floor': 30, 'key': 'REST'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 849099615312600,
#    'circlet_count': 0,
#    'master_deck': ['Defend_B',
#     'Defend_B',
#     'Defend_B',
#     'Zap+1',
#     'Dualcast',
#     'Rebound',
#     'Scrape+1',
#     'Self Repair',
#     'Beam Cell',
#     'Rebound',
#     'Force Field',
#     'Beam Cell',
#     'Rebound',
#     'Amplify',
#     'Leap+1',
#     'Force Field+1',
#     'Bandage Up',
#     'Beam Cell+1',
#     'Streamline+1',
#     'Beam Cell'],
#    'relics': ['Cracked Core',
#     'NeowsBlessing',
#     'Golden Idol',
#     'Mango',
#     'FossilizedHelix',
#     'Ornamental Fan',
#     'Astrolabe',
#     'Regal Pillow'],
#    'potions_floor_usage': [10, 16, 16, 22, 23],
#    'damage_taken': [{'damage': 0,
#      'enemies': 'Jaw Worm',
#      'floor': 1,
#      'turns': 1},
#     {'damage': 0, 'enemies': '2 Louse', 'floor': 5, 'turns': 1},
#     {'damage': 0, 'enemies': '3 Sentries', 'floor': 6, 'turns': 1},
#     {'damage': 0, 'enemies': 'Small Slimes', 'floor': 7, 'turns': 3},
#     {'damage': 0, 'enemies': 'Gremlin Nob', 'floor': 10, 'turns': 3},
#     {'damage': 0, 'enemies': 'Looter', 'floor': 12, 'turns': 2},
#     {'damage': 0, 'enemies': 'Exordium Wildlife', 'floor': 13, 'turns': 3},
#     {'damage': 36, 'enemies': 'Hexaghost', 'floor': 16, 'turns': 7},
#     {'damage': 5, 'enemies': 'Shell Parasite', 'floor': 18, 'turns': 7},
#     {'damage': 22, 'enemies': '3 Byrds', 'floor': 19, 'turns': 6},
#     {'damage': 19,
#      'enemies': 'Shelled Parasite and Fungi',
#      'floor': 21,
#      'turns': 6},
#     {'damage': 38, 'enemies': 'Snake Plant', 'floor': 22, 'turns': 6},
#     {'damage': 24, 'enemies': 'Book of Stabbing', 'floor': 23, 'turns': 4},
#     {'damage': 9, 'enemies': 'Snecko', 'floor': 25, 'turns': 7},
#     {'damage': 48, 'enemies': 'Chosen and Byrds', 'floor': 29, 'turns': 7},
#     {'damage': 73, 'enemies': 'Gremlin Leader', 'floor': 31, 'turns': 4}],
#    'seed_played': '54923944108929939',
#    'potions_obtained': [{'floor': 1, 'key': 'DistilledChaos'},
#     {'floor': 6, 'key': 'PotionOfCapacity'},
#     {'floor': 12, 'key': 'Strength Potion'},
#     {'floor': 16, 'key': 'SmokeBomb'},
#     {'floor': 21, 'key': 'Fruit Juice'},
#     {'floor': 25, 'key': 'Strength Potion'}],
#    'is_trial': False,
#    'path_per_floor': ['M',
#     '$',
#     '?',
#     '?',
#     'M',
#     'E',
#     'M',
#     'R',
#     'T',
#     'E',
#     '?',
#     'M',
#     'M',
#     '$',
#     'R',
#     'B',
#     None,
#     'M',
#     'M',
#     '$',
#     'M',
#     'M',
#     'E',
#     'R',
#     'M',
#     'T',
#     'R',
#     '?',
#     'M',
#     'R',
#     'E'],
#    'character_chosen': 'DEFECT',
#    'items_purchased': ['Scrape', 'Self Repair', 'Rebound', 'Bandage Up'],
#    'campfire_rested': 2,
#    'item_purchase_floors': [2, 2, 14, 20],
#    'current_hp_per_floor': [75,
#     75,
#     64,
#     46,
#     46,
#     60,
#     67,
#     67,
#     67,
#     74,
#     74,
#     74,
#     74,
#     74,
#     74,
#     45,
#     89,
#     89,
#     81,
#     81,
#     66,
#     44,
#     31,
#     59,
#     61,
#     61,
#     61,
#     61,
#     24,
#     67,
#     0,
#     0],
#    'gold': 152,
#    'neow_bonus': 'THREE_ENEMY_KILL',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 3,
#    'win_rate': 0.0,
#    'timestamp': 1601267738,
#    'path_taken': ['M',
#     '$',
#     '?',
#     '?',
#     'M',
#     'E',
#     '?',
#     'R',
#     'T',
#     'E',
#     '?',
#     'M',
#     'M',
#     '$',
#     'R',
#     'BOSS',
#     'M',
#     'M',
#     '$',
#     'M',
#     'M',
#     'E',
#     'R',
#     'M',
#     'T',
#     'R',
#     '?',
#     'M',
#     'R',
#     'E'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 2,
#    'victory': False,
#    'max_hp_per_floor': [75,
#     75,
#     75,
#     75,
#     75,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     89,
#     94,
#     94,
#     94,
#     94,
#     94,
#     94,
#     94,
#     94,
#     94,
#     94,
#     94],
#    'card_choices': [{'not_picked': ['Genetic Algorithm', 'Beam Cell'],
#      'picked': 'Rebound',
#      'floor': 1},
#     {'not_picked': ['Conserve Battery', 'Leap', 'Reinforced Body'],
#      'picked': 'SKIP',
#      'floor': 5},
#     {'not_picked': ['Sweeping Beam', 'Cold Snap', 'Conserve Battery'],
#      'picked': 'SKIP',
#      'floor': 6},
#     {'not_picked': ['Rebound', 'Loop'], 'picked': 'Beam Cell', 'floor': 7},
#     {'not_picked': ['Multi-Cast', 'Hello World'],
#      'picked': 'Rebound',
#      'floor': 10},
#     {'not_picked': ['Tempest', 'Conserve Battery'],
#      'picked': 'Force Field',
#      'floor': 12},
#     {'not_picked': ['Compile Driver', 'Ball Lightning'],
#      'picked': 'Beam Cell',
#      'floor': 13},
#     {'not_picked': ['Biased Cognition', 'Multi-Cast'],
#      'picked': 'Amplify',
#      'floor': 16},
#     {'not_picked': ['Compile Driver+1', 'Fusion', 'Aggregate'],
#      'picked': 'SKIP',
#      'floor': 18},
#     {'not_picked': ['Stack', 'Compile Driver', 'Cold Snap'],
#      'picked': 'SKIP',
#      'floor': 19},
#     {'not_picked': ['Storm', 'Cold Snap', 'Thunder Strike'],
#      'picked': 'SKIP',
#      'floor': 21},
#     {'not_picked': ['Blizzard', 'Hello World'],
#      'picked': 'Beam Cell',
#      'floor': 22},
#     {'not_picked': ['Cold Snap', 'Steam'],
#      'picked': 'Streamline+1',
#      'floor': 25},
#     {'not_picked': ['Barrage', 'Ball Lightning+1'],
#      'picked': 'Beam Cell',
#      'floor': 29}],
#    'player_experience': 212345,
#    'relics_obtained': [{'floor': 6, 'key': 'Mango'},
#     {'floor': 9, 'key': 'FossilizedHelix'},
#     {'floor': 10, 'key': 'Ornamental Fan'},
#     {'floor': 26, 'key': 'Regal Pillow'}],
#    'event_choices': [{'damage_healed': 0,
#      'gold_gain': 75,
#      'player_choice': 'Gather Gold',
#      'damage_taken': 11,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'World of Goop',
#      'floor': 3,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Take Damage',
#      'damage_taken': 18,
#      'relics_obtained': ['Golden Idol'],
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Golden Idol',
#      'floor': 4,
#      'gold_loss': 0},
#     {'cards_removed': ['Defend_B'],
#      'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Card Removal',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'The Cleric',
#      'floor': 11,
#      'gold_loss': 50},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Ignored',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Cursed Tome',
#      'floor': 28,
#      'gold_loss': 0}],
#    'is_beta': False,
#    'boss_relics': [{'not_picked': ['Black Star', 'Busted Crown'],
#      'picked': 'Astrolabe'}],
#    'items_purged_floors': [14, 20],
#    'is_endless': False,
#    'potions_floor_spawned': [1, 6, 12, 16, 21, 23, 25],
#    'killed_by': 'Gremlin Leader',
#    'ascension_level': 0}},
#  {'event': {'gold_per_floor': [113,
#     123,
#     73,
#     73,
#     73,
#     73,
#     107,
#     107,
#     130,
#     156,
#     33,
#     110,
#     138,
#     158,
#     158,
#     256,
#     256,
#     276,
#     290,
#     290,
#     43,
#     53,
#     53,
#     84,
#     47,
#     47,
#     47,
#     47,
#     82,
#     82,
#     82,
#     82,
#     82,
#     82],
#    'floor_reached': 33,
#    'playtime': 1080,
#    'items_purged': ['Strike_R', 'Defend_R'],
#    'score': 299,
#    'play_id': 'e90f77e6-e843-4bf7-bba7-a6053af122ed',
#    'local_time': '20200928123539',
#    'is_ascension_mode': False,
#    'campfire_choices': [{'floor': 6, 'key': 'REST'},
#     {'floor': 15, 'key': 'REST'},
#     {'floor': 27, 'key': 'REST'},
#     {'floor': 32, 'key': 'REST'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 527865072400,
#    'circlet_count': 0,
#    'master_deck': ['Strike_R',
#     'Strike_R',
#     'Strike_R+1',
#     'Defend_R+1',
#     'Defend_R+1',
#     'Defend_R+1',
#     'Bash',
#     'Uppercut',
#     'Dropkick',
#     'Thunderclap',
#     'Offering',
#     'Heavy Blade+1',
#     'Thunderclap+1',
#     'Flash of Steel',
#     'Twin Strike+1',
#     'Metallicize+1',
#     'Normality',
#     'Pommel Strike+1'],
#    'relics': ['Burning Blood',
#     'PreservedInsect',
#     "Charon's Ashes",
#     'Bird Faced Urn',
#     'Boot',
#     'Prayer Wheel',
#     'Frozen Egg 2',
#     'War Paint',
#     'Cursed Key',
#     'Centennial Puzzle',
#     'Molten Egg 2',
#     'Magic Flower',
#     'Ginger'],
#    'potions_floor_usage': [10, 10, 16, 16, 24, 24, 31, 33],
#    'damage_taken': [{'damage': 17,
#      'enemies': 'Small Slimes',
#      'floor': 1,
#      'turns': 3},
#     {'damage': 11, 'enemies': 'Jaw Worm', 'floor': 2, 'turns': 3},
#     {'damage': 13, 'enemies': 'Gremlin Nob', 'floor': 7, 'turns': 4},
#     {'damage': 4, 'enemies': '3 Sentries', 'floor': 10, 'turns': 3},
#     {'damage': 8, 'enemies': 'Gremlin Nob', 'floor': 13, 'turns': 3},
#     {'damage': 0, 'enemies': '2 Louse', 'floor': 14, 'turns': 2},
#     {'damage': 61, 'enemies': 'The Guardian', 'floor': 16, 'turns': 8},
#     {'damage': 18, 'enemies': 'Spheric Guardian', 'floor': 18, 'turns': 4},
#     {'damage': 13, 'enemies': '2 Thieves', 'floor': 19, 'turns': 3},
#     {'damage': 15, 'enemies': 'Snake Plant', 'floor': 22, 'turns': 3},
#     {'damage': 19, 'enemies': 'Slavers', 'floor': 24, 'turns': 2},
#     {'damage': 59, 'enemies': 'Gremlin Leader', 'floor': 29, 'turns': 5},
#     {'damage': 0, 'enemies': 'Centurion and Healer', 'floor': 31, 'turns': 1},
#     {'damage': 14, 'enemies': 'Automaton', 'floor': 33, 'turns': 3}],
#    'seed_played': '-4454664616485705170',
#    'potions_obtained': [{'floor': 1, 'key': 'ColorlessPotion'},
#     {'floor': 7, 'key': 'Explosive Potion'},
#     {'floor': 14, 'key': 'SkillPotion'},
#     {'floor': 16, 'key': 'SmokeBomb'},
#     {'floor': 18, 'key': 'Dexterity Potion'},
#     {'floor': 24, 'key': 'FearPotion'}],
#    'is_trial': False,
#    'path_per_floor': ['M',
#     'M',
#     '?',
#     '$',
#     '?',
#     'R',
#     'E',
#     '?',
#     'T',
#     'E',
#     '$',
#     'T',
#     'E',
#     'M',
#     'R',
#     'B',
#     None,
#     'M',
#     'M',
#     '?',
#     '$',
#     'M',
#     '?',
#     'E',
#     '$',
#     'T',
#     'R',
#     '?',
#     'E',
#     '?',
#     'M',
#     'R',
#     'B'],
#    'character_chosen': 'IRONCLAD',
#    'items_purchased': ['SkillPotion',
#     'Flash of Steel',
#     'AttackPotion',
#     'Metallicize+1'],
#    'campfire_rested': 4,
#    'item_purchase_floors': [11, 21, 21, 25],
#    'current_hp_per_floor': [69,
#     64,
#     64,
#     64,
#     46,
#     70,
#     63,
#     47,
#     47,
#     49,
#     49,
#     49,
#     47,
#     53,
#     77,
#     22,
#     80,
#     68,
#     61,
#     61,
#     61,
#     52,
#     52,
#     39,
#     39,
#     39,
#     63,
#     63,
#     16,
#     16,
#     25,
#     49,
#     35,
#     35],
#    'gold': 82,
#    'neow_bonus': 'RANDOM_COMMON_RELIC',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 0,
#    'win_rate': 0,
#    'timestamp': 1601267739,
#    'path_taken': ['M',
#     'M',
#     '?',
#     '$',
#     '?',
#     'R',
#     'E',
#     '?',
#     'T',
#     'E',
#     '$',
#     '?',
#     'E',
#     '?',
#     'R',
#     'BOSS',
#     'M',
#     '?',
#     '?',
#     '?',
#     '?',
#     '?',
#     'E',
#     '$',
#     'T',
#     'R',
#     '?',
#     'E',
#     '?',
#     '?',
#     'R',
#     'BOSS'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 2,
#    'victory': False,
#    'max_hp_per_floor': [80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80,
#     80],
#    'card_choices': [{'not_picked': ['Pommel Strike', 'Evolve'],
#      'picked': 'Uppercut',
#      'floor': 1},
#     {'not_picked': ['Armaments', 'Second Wind'],
#      'picked': 'Dropkick',
#      'floor': 2},
#     {'not_picked': ['Dark Embrace', 'Shrug It Off', 'Clothesline'],
#      'picked': 'SKIP',
#      'floor': 7},
#     {'not_picked': ['True Grit', 'Searing Blow', 'Flex'],
#      'picked': 'SKIP',
#      'floor': 10},
#     {'not_picked': ['Clothesline', 'Heavy Blade'],
#      'picked': 'Thunderclap',
#      'floor': 13},
#     {'not_picked': ['Searing Blow', 'Power Through', 'Warcry'],
#      'picked': 'SKIP',
#      'floor': 14},
#     {'not_picked': ['Second Wind', 'Barricade+1', 'Flame Barrier'],
#      'picked': 'SKIP',
#      'floor': 14},
#     {'not_picked': ['Barricade+1', 'Fiend Fire'],
#      'picked': 'Offering',
#      'floor': 16},
#     {'not_picked': ['Dual Wield', 'Evolve+1', 'Shrug It Off'],
#      'picked': 'SKIP',
#      'floor': 18},
#     {'not_picked': ['Sword Boomerang', 'Ghostly Armor', 'Perfected Strike+1'],
#      'picked': 'SKIP',
#      'floor': 18},
#     {'not_picked': ['Flame Barrier', 'Burning Pact'],
#      'picked': 'Heavy Blade+1',
#      'floor': 19},
#     {'not_picked': ['Pommel Strike', 'Seeing Red'],
#      'picked': 'Thunderclap+1',
#      'floor': 19},
#     {'not_picked': ['Reckless Charge', 'Rampage+1'],
#      'picked': 'Twin Strike+1',
#      'floor': 22},
#     {'not_picked': ['Hemokinesis', 'Iron Wave', 'Bludgeon'],
#      'picked': 'SKIP',
#      'floor': 22},
#     {'not_picked': ['Iron Wave', 'Flex', 'Body Slam+1'],
#      'picked': 'SKIP',
#      'floor': 24},
#     {'not_picked': ['Sentinel', 'Heavy Blade+1'],
#      'picked': 'Pommel Strike+1',
#      'floor': 29}],
#    'player_experience': 132402,
#    'relics_obtained': [{'floor': 7, 'key': 'Bird Faced Urn'},
#     {'floor': 9, 'key': 'Boot'},
#     {'floor': 10, 'key': 'Prayer Wheel'},
#     {'floor': 12, 'key': 'Frozen Egg 2'},
#     {'floor': 13, 'key': 'War Paint'},
#     {'floor': 24, 'key': 'Centennial Puzzle'},
#     {'floor': 26, 'key': 'Molten Egg 2'},
#     {'floor': 29, 'key': 'Ginger'}],
#    'event_choices': [{'cards_removed': ['Strike_R'],
#      'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Card Removal',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'The Cleric',
#      'floor': 3,
#      'gold_loss': 50},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Success',
#      'damage_taken': 18,
#      'relics_obtained': ["Charon's Ashes"],
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Scrap Ooze',
#      'floor': 5,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Entered Light',
#      'damage_taken': 16,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Shining Light',
#      'floor': 8,
#      'gold_loss': 0,
#      'cards_upgraded': ['Defend_R', 'Strike_R']},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Ignored',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': "N'loth",
#      'floor': 20,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Ignored',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Vampires',
#      'floor': 23,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Opened',
#      'damage_taken': 0,
#      'relics_obtained': ['Magic Flower'],
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'The Mausoleum',
#      'floor': 28,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Ignored',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Cursed Tome',
#      'floor': 30,
#      'gold_loss': 0}],
#    'is_beta': False,
#    'boss_relics': [{'not_picked': ['Runic Dome', 'Black Blood'],
#      'picked': 'Cursed Key'}],
#    'items_purged_floors': [11, 21],
#    'is_endless': False,
#    'potions_floor_spawned': [1, 7, 14, 16, 18, 24],
#    'killed_by': 'Automaton',
#    'ascension_level': 0}},
#  {'event': {'gold_per_floor': [113,
#     113,
#     132,
#     145,
#     157,
#     157,
#     182,
#     182,
#     182,
#     198,
#     198,
#     215,
#     140,
#     173,
#     173,
#     248,
#     248,
#     268,
#     268,
#     280,
#     310,
#     360,
#     360,
#     360],
#    'floor_reached': 23,
#    'playtime': 672,
#    'items_purged': [],
#    'score': 402,
#    'play_id': '48b6ef8b-c65c-439c-983e-8df460904312',
#    'local_time': '20200928123540',
#    'is_ascension_mode': True,
#    'campfire_choices': [{'data': 'Skewer', 'floor': 6, 'key': 'SMITH'},
#     {'data': 'Neutralize', 'floor': 8, 'key': 'SMITH'},
#     {'data': 'Tactician', 'floor': 15, 'key': 'SMITH'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 413093780710400,
#    'circlet_count': 0,
#    'master_deck': ['AscendersBane',
#     'Strike_G',
#     'Strike_G',
#     'Strike_G',
#     'Strike_G',
#     'Defend_G',
#     'Defend_G',
#     'Defend_G',
#     'Defend_G',
#     'Defend_G',
#     'Survivor',
#     'Neutralize+1',
#     'Endless Agony',
#     'Terror',
#     'Tactician+1',
#     'Skewer+1',
#     'Footwork',
#     'Unload',
#     'Ghostly',
#     'Ghostly',
#     'Ghostly',
#     'Expertise'],
#    'special_seed': 0,
#    'relics': ['Ring of the Snake',
#     'NeowsBlessing',
#     'Ornamental Fan',
#     'Letter Opener',
#     'White Beast Statue',
#     'StrikeDummy',
#     'HoveringKite',
#     'Red Mask'],
#    'potions_floor_usage': [7, 16, 16, 18, 20, 21, 23],
#    'damage_taken': [{'damage': 0.0,
#      'enemies': '2 Louse',
#      'floor': 1.0,
#      'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Cultist', 'floor': 3.0, 'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Small Slimes', 'floor': 4.0, 'turns': 1.0},
#     {'damage': 0.0, 'enemies': 'Looter', 'floor': 5.0, 'turns': 2.0},
#     {'damage': 12, 'enemies': 'Lagavulin', 'floor': 7, 'turns': 6},
#     {'damage': 11, 'enemies': '3 Louse', 'floor': 10, 'turns': 4},
#     {'damage': 0, 'enemies': 'Blue Slaver', 'floor': 12, 'turns': 5},
#     {'damage': 19, 'enemies': 'Gremlin Nob', 'floor': 14, 'turns': 4},
#     {'damage': 27, 'enemies': 'Slime Boss', 'floor': 16, 'turns': 13},
#     {'damage': 2, 'enemies': 'Chosen', 'floor': 18, 'turns': 4},
#     {'damage': 9, 'enemies': 'Shell Parasite', 'floor': 20, 'turns': 6},
#     {'damage': 30, 'enemies': 'Masked Bandits', 'floor': 21, 'turns': 7},
#     {'damage': 0, 'enemies': 'Gremlin Leader', 'floor': 23, 'turns': 2}],
#    'seed_played': '2915059910749504125',
#    'potions_obtained': [{'floor': 1.0, 'key': 'SneckoOil'},
#     {'floor': 3.0, 'key': 'SteroidPotion'},
#     {'floor': 5, 'key': 'Energy Potion'},
#     {'floor': 10, 'key': 'DuplicationPotion'},
#     {'floor': 16, 'key': 'Poison Potion'},
#     {'floor': 18, 'key': 'AttackPotion'},
#     {'floor': 20, 'key': 'Regen Potion'},
#     {'floor': 21, 'key': 'FearPotion'}],
#    'is_trial': False,
#    'path_per_floor': ['M',
#     '?',
#     'M',
#     'M',
#     'M',
#     'R',
#     'E',
#     'R',
#     'T',
#     'M',
#     '?',
#     'M',
#     '?',
#     'E',
#     'R',
#     'B',
#     None,
#     'M',
#     '?',
#     'M',
#     '?',
#     '?',
#     'E'],
#    'character_chosen': 'THE_SILENT',
#    'items_purchased': [],
#    'campfire_rested': 0,
#    'item_purchase_floors': [],
#    'current_hp_per_floor': [59,
#     59,
#     59,
#     59,
#     59,
#     59,
#     47,
#     47,
#     47,
#     36,
#     58,
#     58,
#     58,
#     39,
#     39,
#     12,
#     53,
#     51,
#     33,
#     24,
#     6,
#     6,
#     6,
#     6],
#    'gold': 360,
#    'neow_bonus': 'THREE_ENEMY_KILL',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 3,
#    'win_rate': 0,
#    'timestamp': 1601267740,
#    'path_taken': ['M',
#     '?',
#     '?',
#     'M',
#     'M',
#     'R',
#     'E',
#     'R',
#     'T',
#     'M',
#     '?',
#     'M',
#     '?',
#     'E',
#     'R',
#     'BOSS',
#     'M',
#     '?',
#     'M',
#     '?',
#     '?',
#     'E'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 0,
#    'victory': False,
#    'max_hp_per_floor': [66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     66,
#     33,
#     33,
#     33,
#     33,
#     33,
#     33],
#    'card_choices': [{'not_picked': ['PiercingWail', 'Eviscerate'],
#      'picked': 'Endless Agony',
#      'floor': 1.0},
#     {'not_picked': ['Eviscerate', 'Dagger Throw'],
#      'picked': 'Terror',
# ...
#    'relics_obtained': [{'floor': 9, 'key': 'Whetstone'},
#     {'floor': 11, 'key': 'Omamori'},
#     {'floor': 20, 'key': 'Necronomicon'},
#     {'floor': 23, 'key': 'Paper Frog'},
#     {'floor': 25, 'key': 'Boot'},
#     {'floor': 26, 'key': 'Strawberry'},
#     {'floor': 28, 'key': 'Ancient Tea Set'},
#     {'floor': 41, 'key': 'Lizard Tail'},
#     {'floor': 41, 'key': 'Ornamental Fan'},
#     {'floor': 44, 'key': 'Self Forming Clay'}],
#    'event_choices': [{'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Entered Light',
#      'damage_taken': 16,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Shining Light',
#      'floor': 5,
#      'gold_loss': 0,
#      'cards_upgraded': ['Strike_R', 'Defend_R']},
#     {'damage_healed': 18,
#      'gold_gain': 0,
#      'player_choice': 'Full Heal',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Wheel of Change',
#      'floor': 7,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Obtained Book',
#      'damage_taken': 16,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Cursed Tome',
#      'floor': 20,
#      'gold_loss': 0},
#     {'damage_healed': 30,
#      'gold_gain': 0,
#      'player_choice': 'Heal',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'The Library',
#      'floor': 22,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Opened',
#      'damage_taken': 0,
#      'relics_obtained': ['Art of War'],
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'The Mausoleum',
#      'floor': 27,
#      'gold_loss': 0},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'cards_transformed': ['Fire Breathing'],
#      'player_choice': 'Transformed',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Transmorgrifier',
#      'floor': 36,
#      'gold_loss': 0,
#      'cards_obtained': ['Second Wind']},
#     {'damage_healed': 0,
#      'gold_gain': 0,
#      'player_choice': 'Memory 1',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'SensoryStone',
#      'floor': 39,
#      'gold_loss': 0},
#     {'damage_healed': 24,
#      'gold_gain': 0,
#      'player_choice': 'Writhe',
#      'damage_taken': 0,
#      'max_hp_gain': 0,
#      'max_hp_loss': 0,
#      'event_name': 'Winding Halls',
#      'floor': 48,
#      'gold_loss': 0,
#      'cards_obtained': ['Writhe']}],
#    'is_beta': False,
#    'boss_relics': [{'not_picked': ['Cursed Key', 'Fusion Hammer'],
#      'picked': 'Tiny House'},
#     {'not_picked': ['Runic Cube', 'SacredBark'], 'picked': 'Black Star'}],
#    'items_purged_floors': [],
#    'is_endless': False,
#    'potions_floor_spawned': [2, 3, 4, 10, 13, 18, 24, 31, 41, 47],
#    'killed_by': 'Shield and Spear',
#    'ascension_level': 0}},
#  {'event': {'gold_per_floor': [214,
#     231,
#     231,
#     252,
#     265,
#     265,
#     279,
#     279,
#     302,
#     341,
#     98,
#     98,
#     98,
#     131,
#     131,
#     229,
#     229,
#     243,
#     118,
#     143,
#     143,
#     58,
#     58,
#     97,
#     97,
#     168,
#     207,
#     226,
#     244,
#     244,
#     244,
#     244,
#     337,
#     337,
#     361,
#     180,
#     196,
#     209,
#     209,
#     209,
#     222,
#     265,
#     265,
#     296,
#     336,
#     361,
#     384,
#     384,
#     384,
#     384,
#     384,
#     384,
#     94,
#     138,
#     138],
#    'floor_reached': 56,
#    'playtime': 3145,
#    'items_purged': ['Strike_B', 'Defend_B', 'Defend_B', 'Defend_B'],
#    'score': 2219,
#    'play_id': '8f6cf704-54b4-4c45-88e2-899108783cbb',
#    'local_time': '20200928133549',
#    'is_ascension_mode': True,
#    'campfire_choices': [{'data': 'Dualcast', 'floor': 6.0, 'key': 'SMITH'},
#     {'data': 'Consume', 'floor': 8.0, 'key': 'SMITH'},
#     {'data': 'Capacitor', 'floor': 13.0, 'key': 'SMITH'},
#     {'data': 'Turbo', 'floor': 15.0, 'key': 'SMITH'},
#     {'data': 'Recycle', 'floor': 23.0, 'key': 'SMITH'},
#     {'data': 'Coolheaded', 'floor': 25.0, 'key': 'SMITH'},
#     {'floor': 30.0, 'key': 'REST'},
#     {'floor': 32.0, 'key': 'REST'},
#     {'data': 'Seek', 'floor': 40.0, 'key': 'SMITH'},
#     {'floor': 49.0, 'key': 'RECALL'},
#     {'data': 'Amplify', 'floor': 52.0, 'key': 'SMITH'}],
#    'neow_cost': 'NONE',
#    'seed_source_timestamp': 0,
#    'circlet_count': 0,
#    'master_deck': ['AscendersBane',
#     'Zap',
#     'Dualcast+1',
#     'Ball Lightning',
#     'Ball Lightning',
#     'Consume+1',
#     'Glacier',
#     'Defragment+1',
#     'Capacitor+1',
#     'Turbo+1',
#     'Electrodynamics',
#     'Thunder Strike+1',
#     'Glacier+1',
#     'Undo+1',
#     'Hologram',
#     'Coolheaded+1',
#     'Recycle+1',
#     'Creative AI',
#     'Capacitor',
#     'Seek+1',
#     'Compile Driver',
#     'Coolheaded+1',
#     'Amplify+1',
#     'Defragment+1',
#     'Capacitor',
#     'Reboot'],
#    'special_seed': 0,
#    'relics': ['Cracked Core',
#     'Golden Idol',
#     'Toy Ornithopter',
#     'Happy Flower',
#     'DataDisk',
#     'Astrolabe',
#     'Bag of Preparation',
#     'Peace Pipe',
#     'Singing Bowl',
#     'Red Mask',
#     'Coffee Dripper',
#     'StrikeDummy',
#     'Incense Burner',
#     'Question Card',
#     'Gambling Chip'],
#    'potions_floor_usage': [55],
#    'damage_taken': [{'damage': 9.0,
#      'enemies': 'Jaw Worm',
#      'floor': 1.0,
#      'turns': 4.0},
#     {'damage': 0.0, 'enemies': 'Small Slimes', 'floor': 2.0, 'turns': 2.0},
#     {'damage': 1.0, 'enemies': 'Cultist', 'floor': 4.0, 'turns': 3.0},
#     {'damage': 12.0, 'enemies': 'Looter', 'floor': 5.0, 'turns': 3.0},
#     {'damage': 6.0, 'enemies': 'Blue Slaver', 'floor': 7.0, 'turns': 3.0},
#     {'damage': 24.0, 'enemies': 'Gremlin Nob', 'floor': 10.0, 'turns': 4.0},
#     {'damage': 25.0, 'enemies': '3 Sentries', 'floor': 14.0, 'turns': 5.0},
#     {'damage': 0.0, 'enemies': 'Hexaghost', 'floor': 16.0, 'turns': 8.0},
#     {'damage': 0.0,
#      'enemies': 'Spheric Guardian',
#      'floor': 18.0,
#      'turns': 4.0},
#     {'damage': 0.0, 'enemies': 'Shell Parasite', 'floor': 20.0, 'turns': 5.0},
#     {'damage': 35.0, 'enemies': 'Slavers', 'floor': 24.0, 'turns': 4.0},
#     {'damage': 19.0, 'enemies': 'Masked Bandits', 'floor': 27.0, 'turns': 4.0},
#     {'damage': 2.0,
#      'enemies': 'Chosen and Byrds',
#      'floor': 28.0,
#      'turns': 5.0},
#     {'damage': 0.0,
#      'enemies': 'Shelled Parasite and Fungi',
#      'floor': 29.0,
#      'turns': 8.0},
#     {'damage': 19.0, 'enemies': 'Automaton', 'floor': 33.0, 'turns': 10.0},
#     {'damage': 7.0, 'enemies': 'Orb Walker', 'floor': 35.0, 'turns': 5.0},
#     {'damage': 0.0, 'enemies': '3 Shapes', 'floor': 37.0, 'turns': 3.0},
#     {'damage': 0.0,
#      'enemies': 'Sphere and 2 Shapes',
#      'floor': 38.0,
#      'turns': 4.0},
#     {'damage': 0.0, 'enemies': 'Maw', 'floor': 41.0, 'turns': 9.0},
#     {'damage': 0.0, 'enemies': 'Nemesis', 'floor': 42.0, 'turns': 8.0},
#     {'damage': 0.0,
#      'enemies': 'Mind Bloom Boss Battle',
#      'floor': 44.0,
#      'turns': 5.0},
#     {'damage': 0.0, 'enemies': 'Giant Head', 'floor': 45.0, 'turns': 8.0},
#     {'damage': 2.0, 'enemies': 'Jaw Worm Horde', 'floor': 46.0, 'turns': 3.0},
#     {'damage': 5.0, 'enemies': 'Spire Growth', 'floor': 47.0, 'turns': 5.0},
#     {'damage': 8.0, 'enemies': 'Donu and Deca', 'floor': 50.0, 'turns': 5.0},
#     {'damage': 8.0,
#      'enemies': 'Shield and Spear',
#      'floor': 54.0,
#      'turns': 6.0},
#     {'damage': 70, 'enemies': 'The Heart', 'floor': 55, 'turns': 12}],
#    'seed_played': '-2890748624604183144',
#    'potions_obtained': [{'floor': 4.0, 'key': 'GamblersBrew'},
#     {'floor': 5.0, 'key': 'Explosive Potion'},
#     {'floor': 14.0, 'key': 'FearPotion'},
#     {'floor': 16.0, 'key': 'Swift Potion'},
#     {'floor': 20.0, 'key': 'Dexterity Potion'},
#     {'floor': 28.0, 'key': 'Dexterity Potion'},
#     {'floor': 33.0, 'key': 'SteroidPotion'},
#     {'floor': 38.0, 'key': 'Weak Potion'},
#     {'floor': 42.0, 'key': 'PotionOfCapacity'}],
#    'is_trial': False,
#    'path_per_floor': ['M',
#     'M',
#     '?',
#     'M',
#     'M',
#     'R',
#     'M',
#     'R',
#     'T',
#     'E',
#     '$',
#     '?',
#     'R',
#     'E',
#     'R',
#     'B',
#     None,
#     'M',
#     '$',
#     'M',
#     '?',
#     '?',
#     'R',
#     'E',
#     'R',
#     'T',
#     '?',
#     'M',
#     'M',
#     'R',
#     '?',
#     'R',
#     'B',
#     None,
#     'M',
#     '$',
#     'M',
#     'M',
#     '?',
#     'R',
#     'M',
#     'E',
#     'T',
#     '?',
#     'E',
#     'M',
#     'M',
#     '?',
#     'R',
#     'B',
#     None,
#     'R',
#     '$',
#     'E',
#     'B',
#     None],
#    'character_chosen': 'DEFECT',
#    'items_purchased': ['Capacitor',
#     'Regen Potion',
#     'Coolheaded',
#     'Compile Driver',
#     'Capacitor',
#     'PowerPotion'],
#    'campfire_rested': 2,
#    'item_purchase_floors': [11, 11, 19, 36, 53, 53],
#    'current_hp_per_floor': [55,
#     55,
#     55,
#     54,
#     42,
#     42,
#     36,
#     36,
#     36,
#     17,
#     17,
#     17,
#     17,
#     16,
#     16,
#     16,
#     52,
#     52,
#     52,
#     57,
#     57,
#     57,
#     57,
#     27,
#     27,
#     27,
#     10,
#     10,
#     10,
#     30,
#     30,
#     50,
#     36,
#     60,
#     55,
#     55,
#     55,
#     57,
#     57,
#     57,
#     59,
#     61,
#     61,
#     63,
#     65,
#     63,
#     58,
#     58,
#     58,
#     50,
#     70,
#     70,
#     70,
#     67,
#     2],
#    'gold': 138,
#    'neow_bonus': 'HUNDRED_GOLD',
#    'is_prod': False,
#    'is_daily': False,
#    'chose_seed': False,
#    'campfire_upgraded': 8,
#    'win_rate': 0,
#    'timestamp': 1601267749,
#    'path_taken': ['M',
#     'M',
#     '?',
#     'M',
#     'M',
#     'R',
#     'M',
#     'R',
#     'T',
#     'E',
#     '$',
#     '?',
#     'R',
#     'E',
#     'R',
#     'BOSS',
#     'M',
#     '$',
#     'M',
#     '?',
#     '?',
#     'R',
#     'E',
#     'R',
#     'T',
#     '?',
#     'M',
#     'M',
#     'R',
#     '?',
#     'R',
#     'BOSS',
#     'M',
#     '$',
#     'M',
#     'M',
#     '?',
#     'R',
#     '?',
#     'E',
#     'T',
#     '?',
#     'E',
#     'M',
#     'M',
#     '?',
#     'R',
#     'BOSS',
#     'R',
#     '$',
#     'E',
#     'BOSS'],
#    'build_version': '2020-07-30',
#    'purchased_purges': 4,
#    'victory': True,
#    'max_hp_per_floor': [71,
#     71,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     64,
#     66,
#     68,
#     68,
#     68,
#     68,
#     68,
#     68,
#     68,
#     70,
#     70,
#     70,
#     72,
#     72,
#     72,
#     74,
#     76,
#     76,
#     78,
#     80,
#     80,
#     80,
#     76,
#     76,
#     76,
#     76,
#     76,
#     76,
#     76,
#     76],
#    'card_choices': [{'not_picked': ['Tempest', 'Hologram'],
#      'picked': 'Ball Lightning',
#      'floor': 1.0},
#     {'not_picked': ['Steam', 'Redo'],
#      'picked': 'Ball Lightning',
#      'floor': 2.0},
#     {'not_picked': ['Streamline', 'Steam'], 'picked': 'Consume', 'floor': 4.0},
#     {'not_picked': ['Genetic Algorithm', 'Recycle'],
#      'picked': 'Glacier',
#      'floor': 5.0},
#     {'not_picked': ['Force Field', 'Barrage', 'Go for the Eyes'],
#      'picked': 'SKIP',
#      'floor': 7.0},
#     {'not_picked': ['Cold Snap', 'Glacier'],
#      'picked': 'Defragment',
#      'floor': 10.0},
#     {'not_picked': ['Leap', 'Force Field'], 'picked': 'Turbo', 'floor': 14.0},
#     {'not_picked': ['Rainbow', 'Reboot'],
#      'picked': 'Electrodynamics',
#      'floor': 16.0},
#     {'not_picked': ['Stack', 'Go for the Eyes'],
#      'picked': 'Hologram',
#      'floor': 18.0},
#     {'not_picked': ['Rebound', 'Turbo'], 'picked': 'Recycle', 'floor': 20.0},
#     {'not_picked': ['Hello World', 'Tempest'],
#      'picked': 'Creative AI',
#      'floor': 24.0},
#     {'not_picked': ['Rebound', 'Stack', 'Steam'],
#      'picked': 'Singing Bowl',
#      'floor': 27.0},
#     {'not_picked': ['Storm', 'Double Energy', 'Beam Cell'],
#      'picked': 'Singing Bowl',
#      'floor': 28.0},
#     {'not_picked': ['FTL', 'Reprogram'], 'picked': 'Capacitor', 'floor': 29.0},
#     {'not_picked': ['Buffer', 'Hyperbeam'], 'picked': 'Seek', 'floor': 33.0},
#     {'not_picked': ['Coolheaded', 'Rebound', 'Reinforced Body'],
#      'picked': 'Singing Bowl',
#      'floor': 35.0},
#     {'not_picked': ['Scrape+1', 'Leap'],
#      'picked': 'Coolheaded+1',
#      'floor': 37.0},
#     {'not_picked': ['Stack+1', 'Reprogram', 'Sweeping Beam'],
#      'picked': 'Singing Bowl',
#      'floor': 38.0},
#     {'not_picked': ['Loop', 'Gash+1', 'Ball Lightning'],
#      'picked': 'Singing Bowl',
#      'floor': 41.0},
#     {'not_picked': ['Tempest', 'Sweeping Beam+1', 'Blizzard'],
#      'picked': 'Singing Bowl',
#      'floor': 42.0},
#     {'not_picked': ['Lockon', 'Coolheaded', 'Go for the Eyes'],
#      'picked': 'Singing Bowl',
#      'floor': 44.0},
#     {'not_picked': ['Chaos', 'Go for the Eyes', 'Reprogram'],
#      'picked': 'Singing Bowl',
#      'floor': 45.0},
#     {'not_picked': ['Loop', 'Reinforced Body', 'Beam Cell'],
#      'picked': 'Amplify',
#      'floor': 46.0},
#     {'not_picked': ['Melter', 'Stack', 'Steam Power'],
#      'picked': 'Defragment+1',
#      'floor': 47.0},
#     {'not_picked': ['Barrage+1', 'Compile Driver', 'Aggregate+1'],
#      'picked': 'Reboot',
#      'floor': 54.0}],
#    'player_experience': 136197,
#    'relics_obtained': [{'floor': 9.0, 'key': 'Toy Ornithopter'},
#     {'floor': 10.0, 'key': 'Happy Flower'},
#     {'floor': 14.0, 'key': 'DataDisk'},
#     {'floor': 24.0, 'key': 'Peace Pipe'},
#     {'floor': 26.0, 'key': 'Singing Bowl'},
#     {'floor': 27.0, 'key': 'Red Mask'},
#     {'floor': 42.0, 'key': 'StrikeDummy'},
#     {'floor': 44.0, 'key': 'Incense Burner'},
#     {'floor': 45.0, 'key': 'Question Card'},
#     {'floor': 54.0, 'key': 'Gambling Chip'}],
#    'event_choices': [{'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 7.0,
#      'gold_gain': 0.0,
#      'event_name': 'Golden Idol',
#      'player_choice': 'Lose Max HP',
#      'floor': 3.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'relics_obtained': ['Golden Idol']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Accursed Blacksmith',
#      'player_choice': 'Forge',
#      'floor': 12.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0,
#      'cards_upgraded': ['Defragment']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Ghosts',
#      'player_choice': 'Ignored',
#      'floor': 21.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Addict',
#      'player_choice': 'Obtained Relic',
#      'floor': 22.0,
#      'gold_loss': 85.0,
#      'damage_taken': 0.0,
#      'relics_obtained': ['Bag of Preparation']},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Masked Bandits',
#      'player_choice': 'Fought Bandits',
#      'floor': 27.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'cards_removed': ['Defend_B'],
#      'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'Purifier',
#      'player_choice': 'Purged',
#      'floor': 31.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'SecretPortal',
#      'player_choice': 'Ignored',
#      'floor': 39.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 0.0,
#      'gold_gain': 0.0,
#      'event_name': 'MindBloom',
#      'player_choice': 'Fight',
#      'floor': 44.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0},
#     {'damage_healed': 0.0,
#      'max_hp_gain': 0.0,
#      'max_hp_loss': 4.0,
#      'gold_gain': 0.0,
#      'event_name': 'Winding Halls',
#      'player_choice': 'Max HP',
#      'floor': 48.0,
#      'gold_loss': 0.0,
#      'damage_taken': 0.0}],
#    'is_beta': False,
#    'boss_relics': [{'not_picked': ['Black Star', 'Busted Crown'],
#      'picked': 'Astrolabe'},
#     {'not_picked': ['FrozenCore', 'SlaversCollar'],
#      'picked': 'Coffee Dripper'}],
#    'items_purged_floors': [11, 19, 36, 53],
#    'is_endless': False,
#    'potions_floor_spawned': [4, 5, 14, 16, 20, 28, 33, 38, 42, 44, 46],
#    'ascension_level': 18}}]

# %%
sample = run[:20]

for i, r in enumerate(sample):
    event = r['event']
    print(i, event.get('character_chosen'), event.get('floor_reached'), event.get('victory'), len(event.get('card_choices', [])))
# Out:
# 0 DEFECT 24 False 12
# 1 DEFECT 54 False 28
# 2 IRONCLAD 5 False 2
# 3 IRONCLAD 10 False 4
# 4 THE_SILENT 7 False 2
# 5 DEFECT 31 False 14
# 6 IRONCLAD 33 False 16
# 7 THE_SILENT 23 False 11
# 8 WATCHER 33 False 13
# 9 IRONCLAD 24 False 10
# 10 DEFECT 0 False 0
# 11 IRONCLAD 25 False 12
# 12 DEFECT 7 False 3
# 13 IRONCLAD 1 False 0
# 14 IRONCLAD 17 False 7
# 15 IRONCLAD 50 False 23
# 16 IRONCLAD 19 False 7
# 17 THE_SILENT 22 False 14
# 18 IRONCLAD 54 False 28
# 19 DEFECT 56 True 25
